# %% [markdown]
# # Filtering topics

# %% [markdown]
# ## Initialization

# %%
import pandas as pd
import numpy as np
import pickle
import tqdm
import plotly.express as px
import os

# %%
PATH_DIR = './'
os.chdir(PATH_DIR)

# %%
PATH = 'Data/bert_out/'
FILE_NAME = 'topic_distr_original'

with open(PATH+FILE_NAME+'.pickle', 'rb') as handle:
    topic_distr = pickle.load(handle)

topic_distr
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.024797  0.011705  0.010693  0.008375  0.005628  0.018542  0.020291
# 1      0.040935  0.000000  0.040133  0.000000  0.033549  0.029655  0.025441
# 2      0.012864  0.021521  0.009310  0.010332  0.009723  0.014192  0.012019
# 3      0.011270  0.016598  0.010866  0.000000  0.007408  0.021291  0.000000
# 4      0.013652  0.024821  0.008584  0.007621  0.005711  0.013430  0.008990
# ...         ...       ...       ...       ...       ...       ...       ...
# 92823  0.015265  0.014507  0.006162  0.008193  0.006817  0.015499  0.011959
# 92824  0.016893  0.017005  0.009695  0.007517  0.000000  0.024585  0.023215
# 92825  0.011575  0.016199  0.007878  0.000000  0.004853  0.017223  0.006641
# 92826  0.012377  0.013047  0.011152  0.008696  0.000000  0.016131  0.008041
# 92827  0.013417  0.015136  0.009987  0.007308  0.006966  0.016261  0.010538
#
#             7         8         9    ...       92        93        94   \
# 0      0.004845  0.008754  0.008264  ...  0.012315  0.006511  0.008253
# 1      0.000000  0.025226  0.000000  ...  0.000000  0.000000  0.000000
# 2      0.010545  0.010255  0.010771  ...  0.007341  0.011818  0.010794
# 3      0.000000  0.013026  0.021692  ...  0.014128  0.010863  0.012475
# 4      0.008046  0.007147  0.017659  ...  0.009970  0.012323  0.009855
# ...         ...       ...       ...  ...       ...       ...       ...
# 92823  0.007650  0.011001  0.010540  ...  0.008193  0.007293  0.005387
# 92824  0.007745  0.000000  0.010414  ...  0.008897  0.011413  0.000000
# 92825  0.004726  0.006566  0.011706  ...  0.008648  0.013275  0.009290
# 92826  0.012153  0.000000  0.008125  ...  0.007397  0.007312  0.014083
# 92827  0.009528  0.011322  0.012689  ...  0.007797  0.008498  0.009416
#
#             95        96        97        98        99        100       101
# 0      0.009008  0.011415  0.013037  0.004864  0.015753  0.013542  0.008988
# 1      0.000000  0.032615  0.000000  0.024874  0.000000  0.000000  0.000000
# 2      0.009102  0.008880  0.006091  0.008485  0.009068  0.007105  0.009315
# 3      0.012540  0.000000  0.014832  0.000000  0.016253  0.000000  0.014646
# 4      0.006026  0.009519  0.013055  0.000000  0.007105  0.006700  0.011197
# ...         ...       ...       ...       ...       ...       ...       ...
# 92823  0.010188  0.010505  0.010320  0.010541  0.009675  0.009273  0.008920
# 92824  0.012517  0.010195  0.012201  0.024589  0.007866  0.008193  0.000000
# 92825  0.008208  0.007408  0.040022  0.005015  0.017245  0.010282  0.010724
# 92826  0.000000  0.008264  0.006892  0.010266  0.012969  0.012778  0.016228
# 92827  0.009864  0.007553  0.007309  0.007054  0.010263  0.010774  0.009147
#
# [92828 rows x 102 columns]

# %% [markdown]
# ## Visualization

# %%
def visualize_thresholds(topic_distr, lower_thr=0, upper_thr=1):
  tmp_dfs = []

  # iterating through different threshold levels
  for thr in tqdm.tqdm(np.arange(lower_thr, upper_thr, 0.001)):

      tmp_df = pd.DataFrame()
      tmp_df['num_topics'] = topic_distr[ topic_distr >= thr ].count(axis=1)

      tmp_df['num_docs'] = 1

      tmp_df['num_topics_group'] = tmp_df['num_topics']\
          .map(lambda x: str(x) if x < 5 else '5+')

      # aggregating stats
      tmp_df_aggr = tmp_df.groupby('num_topics_group', as_index = False).num_docs.sum()
      tmp_df_aggr['threshold'] = thr

      tmp_dfs.append(tmp_df_aggr)

  num_topics_stats_df = pd.concat(tmp_dfs).pivot(index = 'threshold',
                                values = 'num_docs',
                                columns = 'num_topics_group').fillna(0)

  num_topics_stats_df = num_topics_stats_df.apply(lambda x: 100.*x/num_topics_stats_df.sum(axis = 1))

  # visualisation
  colormap = px.colors.sequential.YlGnBu
  return px.area(num_topics_stats_df,
        title = 'Distribution of number of topics',
        labels = {'num_topics_group': 'number of topics',
                  'value': 'percentage of tweets'},
        color_discrete_map = {
            '0': colormap[0],
            '1': colormap[3],
            '2': colormap[4],
            '3': colormap[5],
            '4': colormap[6],
            '5+': colormap[7]
        })

# %%
visualize_thresholds(topic_distr)
# Out:
# 100%|██████████| 1000/1000 [01:23<00:00, 11.94it/s]

# %%
visualize_thresholds(topic_distr, lower_thr=0, upper_thr=0.03)
# 0.018 - 0.02
# Out:
# 100%|██████████| 30/30 [00:02<00:00, 12.77it/s]

# %% [markdown]
# ## Topics

# %%
PATH = 'Data/'
PATH_FILE_XLSX = 'topic_stats'

df_topics = pd.read_excel(PATH+PATH_FILE_XLSX+'.xlsx', engine='openpyxl')

# %%
df_topics.head()
# Out:
#    Unnamed: 0  Topic  Count                                     Name  \
# 0           0     -1  58626                    -1_like_rt_one_people
# 1           1      0   5651            0_tag_follow_giveaway_retweet
# 2           2      1   2987  1_birthday_happy birthday_happy_morning
# 3           3      2   2442               2_song_album_music_spotify
# 4           4      3   2225              3_trump_biden_president_fbi
#
#                   Name_1 Name_2                  Name_3  \
# 0                    NaN    NaN                     NaN
# 1  Contest Participation    NaN            Social Media
# 2    General Expressions    NaN     General Expressions
# 3                  Music    NaN           Entertainment
# 4            US Politics    NaN  Politics and Conflicts
#
#                                       Representation  \
# 0  ['like', 'rt', 'one', 'people', 'get', 'follow...
# 1  ['tag', 'follow', 'giveaway', 'retweet', 'tag ...
# 2  ['birthday', 'happy birthday', 'happy', 'morni...
# 3  ['song', 'album', 'music', 'spotify', 'songs',...
# 4  ['trump', 'biden', 'president', 'fbi', 'donald...
#
#                                  Representative_Docs
# 0  ['mins rt rt like', 'k hours rt follow', 'k ho...
# 1  ['giveaway x og spots enter follow like rt tag...
# 2  ['happy birthday', 'happy birthday', 'happy bi...
# 3  ['seokjin shazam record holder seokjin represe...
# 4  ['say president trump hes president anymore su...

# %%
PATH = 'Data/Original dataset 11-2022/'
FILE_NAME = 'filtered_tweets'
df_tweets = pd.read_excel(PATH+FILE_NAME+'.xlsx', engine='openpyxl')

# %%
df_tweets.head()
# Out:
#    Unnamed: 0             tweet_id              user_id  \
# 0           0  1587232917985512960  1340915697384209920
# 1           1  1586896938363802112  1113923052084113024
# 2           2  1587232917947929088   768539405472542720
# 3           3  1587232917972999936  1582752440780313088
# 4           4  1587109985929945088  1262722155357199872
#
#                                                 text  \
# 0  RT @sergioisbetter: ‼️‼️💚SALE ENDING SOON💚‼️‼️...
# 1  ‼️‼️💚SALE ENDING SOON💚‼️‼️\nWatch our latest h...
# 2  Now playing: WJIC Network ID by The WJIC Netwo...
# 3  RT @Kyzef: Good morning mfers ☀️ Hope everybod...
# 4  Good morning mfers ☀️ Hope everybody has a gre...
#
#                        created_at  in_reply_to_status_id  in_reply_to_user_id  \
# 0  Mon Oct 31 23:59:51 +0000 2022                    NaN                  NaN
# 1  Mon Oct 31 01:44:47 +0000 2022                    NaN                  NaN
# 2  Mon Oct 31 23:59:51 +0000 2022                    NaN                  NaN
# 3  Mon Oct 31 23:59:51 +0000 2022                    NaN                  NaN
# 4  Mon Oct 31 15:51:22 +0000 2022                    NaN                  NaN
#
#    quote_count  reply_count  retweet_count  ...  \
# 0            0            0              0  ...
# 1            2           10            787  ...
# 2            0            0              0  ...
# 3            0            0              0  ...
# 4            0           23              8  ...
#
#                                             entities   type  \
# 0  {'hashtags': [], 'urls': [{'url': 'https://t.c...     RT
# 1  {'hashtags': [], 'urls': [{'url': 'https://t.c...  tweet
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...  tweet
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...     RT
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...  tweet
#
#                                        filtered_text  \
# 0                                                NaN
# 1  sale ending soon watch latest hottest collab n...
# 2   playing wjic network id wjic network listen live
# 3                                                NaN
# 4  good morning mfers hope everybody great halloween
#
#                                       tokenized_text  \
# 0                                                NaN
# 1  $EMOJI$SALE ENDING SOON$EMOJI$Watch our latest...
# 2  Now playing: WJIC Network ID by The WJIC Netwo...
# 3                                                NaN
# 4  Good morning mfers $EMOJI$ Hope everybody has ...
#
#                                         stemmed_text hashtags      emojis  \
# 0                                                NaN       []          []
# 1   sale end soon watch latest hottest collab new...       []  ['💚', '💚']
# 2      play wjic network id wjic network listen live       []          []
# 3                                                NaN       []          []
# 4      good morn mfer hope everybodi great halloween       []       ['☀']
#
#   smileys numbers                                               urls
# 0      []      []                                                 []
# 1      []      []  ['https://t.co/kGpSdd3HUR', 'https://t.co/MPkU...
# 2      []      []                        ['https://t.co/Lzezf1IpOn']
# 3      []      []                                                 []
# 4      []      []                                                 []
#
# [5 rows x 21 columns]

# %%
def create_topics_dictionary(df_topics):
  topics_dict = {}

  for i in range(1,len(df_topics)):
    topics_dict[df_topics['Topic'][i]] = []
    topics_dict[df_topics['Topic'][i]].append(df_topics['Name_3'][i])

    if (pd.notnull(df_topics['Name_2'][i])):
      topics_dict[df_topics['Topic'][i]].append(df_topics['Name_2'][i])
      
    if (df_topics['Name_1'][i] not in topics_dict[df_topics['Topic'][i]]):
      topics_dict[df_topics['Topic'][i]].append(df_topics['Name_1'][i])

  return topics_dict

def get_topic_scores(df, topic_list, idx):
  topics = []
  scores = []

  for x in topic_list:
    topics.append(x)
    scores.append(df.loc[idx][x])

  return {'Topics': topics, 'Scores': scores}

def get_topic_names(df, topic_names, topic_list, idx, specific_topics=False):
  dictionary = {}
  min_iters = 0
  max_iters = 1

  for x in topic_list:
    if (specific_topics == True):
      min_iters = 1
      max_iters = len(topic_names[x])

    for i in range(min_iters, max_iters):
      if (topic_names[x][i] not in dictionary.keys()):
        dictionary[topic_names[x][i]] = df.loc[idx][x]
      else:
        dictionary[topic_names[x][i]] += df.loc[idx][x]

  return {'Topics': dictionary.keys(), 'Scores': dictionary.values()}

def get_relevant_topics(df, threshold, topic_names):
  df_topics = pd.DataFrame()
  df_topics['topics_list'] = df.apply(lambda row: get_topic_scores(df, row[row >= threshold].index.tolist(), row.name), axis=1)
  df_topics['topics_list_general'] = df.apply(lambda row: get_topic_names(df, topic_names, row[row >= threshold].index.tolist(), row.name), axis=1)
  df_topics['topics_list_specific'] = df.apply(lambda row: get_topic_names(df, topic_names, row[row >= threshold].index.tolist(), row.name, specific_topics=True), axis=1)
  return df_topics

def combine_datasets(df_tweets, df_topic_distr):
  df_final = pd.DataFrame()
  df_final = df_tweets.copy(deep=True)
  df_final.loc[pd.notna(df_final['filtered_text']), 'topics_list'] = df_topic_distr['topics_list'].values
  df_final.loc[pd.notna(df_final['filtered_text']), 'topics_list_general'] = df_topic_distr['topics_list_general'].values
  df_final.loc[pd.notna(df_final['filtered_text']), 'topics_list_specific'] = df_topic_distr['topics_list_specific'].values

  return df_final

# %%
topics_dict = create_topics_dictionary(df_topics)
topics_dict
# Out:
# {0: ['Social Media', 'Contest Participation'],
#  1: ['General Expressions'],
#  2: ['Entertainment', 'Music'],
#  3: ['Politics and Conflicts', 'US Politics'],
#  4: ['Politics and Conflicts', 'Ukraine Conflict'],
#  5: ['General Expressions'],
#  6: ['Finance', 'Cryptocurrency'],
#  7: ['Religion', 'Hinduism/Islam'],
#  8: ['Sports', 'American Football/Basketball'],
#  9: ['Food'],
#  10: ['Sports', 'Football'],
#  11: ['Social Interactions and Relationships', 'Family'],
#  12: ['Education'],
#  13: ['Art and Creativity', 'Fashion'],
#  14: ['Religion', 'Christianity'],
#  15: ['Art and Creativity', 'Art'],
#  16: ['Transportation'],
#  17: ['Politics and Conflicts', 'Tigray Conflict'],
#  18: ['Other', 'Names'],
#  19: ['Entertainment', 'Literature'],
#  20: ['Entertainment', 'Music', 'KPop'],
#  21: ['Health'],
#  22: ['General Expressions', 'Positive Expressions'],
#  23: ['Politics and Conflicts', 'UK Politics'],
#  24: ['Emotions', 'Love and Happiness'],
#  25: ['Other', 'Adult Content'],
#  26: ['Social Media', 'Social Media Engagement'],
#  27: ['Politics and Conflicts', 'Nigeria'],
#  28: ['Art and Creativity', 'Photography'],
#  29: ['Politics and Conflicts', 'Gender and Identity'],
#  30: ['General Expressions', 'Positive Expressions'],
#  31: ['Other', 'Weather'],
#  32: ['Finance', 'Cryptocurrency'],
#  33: ['Other', 'Time'],
#  34: ['Finance'],
#  35: ['General Expressions', 'Slang and Informal Language'],
#  36: ['Emotions', 'Crying'],
#  37: ['Other', 'Project and Development'],
#  38: ['Other', 'Completion'],
#  39: ['Physical Activity', 'Hands and Fitness'],
#  40: ['Entertainment', 'Music', 'KPop'],
#  41: ['Politics and Conflicts', 'Abortion Rights'],
#  42: ['Politics and Conflicts', 'Race and Racism'],
#  43: ['Social Interactions and Relationships', 'Friendship'],
#  44: ['Nature and Environment', 'Nature and Animals'],
#  45: ['Finance', 'NFTs and Crypto'],
#  46: ['Animals', 'Dogs and Pets'],
#  47: ['Other', 'Heart'],
#  48: ['Art and Creativity', 'Hair Styles'],
#  49: ['Sports', 'Fighting and Combat Sports'],
#  50: ['General Expressions', 'Smiles and Hugs'],
#  51: ['General Expressions', 'Laughter and Humor'],
#  52: ['Social Interactions and Relationships', 'Marriage'],
#  53: ['Social Media', 'Social Media Engagement'],
#  54: ['Other', 'Colors'],
#  55: ['Other', 'Moon and Space'],
#  56: ['Nature and Environment', 'Environment and Climate'],
#  57: ['Entertainment', 'Gaming'],
#  58: ['Entertainment', 'Music', 'KPop'],
#  59: ['Social Media', 'Communication and Customer Service'],
#  60: ['General Expressions'],
#  61: ['General Expressions', 'Communication'],
#  62: ['Other', 'Voting'],
#  63: ['Animals', 'Cats'],
#  64: ['Sports', 'Cricket'],
#  65: ['Social Media', 'Social Media Engagement'],
#  66: ['General Expressions', 'Missing and Longing'],
#  67: ['General Expressions', 'Gratitude'],
#  68: ['Politics and Conflicts', 'Royalty'],
#  69: ['Social Interactions and Relationships', 'Kissing and Affection'],
#  70: ['Other', 'Adult Content', 'Breasts'],
#  71: ['General Expressions', 'Hope and Expectation'],
#  72: ['General Expressions'],
#  73: ['General Expressions', 'Congratulations'],
#  74: ['Physical Attributes', 'Age and Growing'],
#  75: ['Other', 'Shooting and Weapons'],
#  76: ['General Expressions', 'Lying'],
#  77: ['Entertainment', 'Fandom'],
#  78: ['Other', 'Home'],
#  79: ['Emotions', 'Love'],
#  80: ['Health', 'Masks'],
#  81: ['General Expressions', 'Memory and Remembering'],
#  82: ['Drinking and Alcohol'],
#  83: ['Other', 'Zodiac Signs'],
#  84: ['Other'],
#  85: ['General Expressions'],
#  86: ['Entertainment', 'Music', 'KPop'],
#  87: ['General Expressions', 'Communication'],
#  88: ['Other', 'Fire and Burning'],
#  89: ['Emotions', 'Feeling'],
#  90: ['Physical Activity'],
#  91: ['Physical Attributes', 'Face and Body'],
#  92: ['Entertainment', 'TikTok'],
#  93: ['Emotions', 'Mood'],
#  94: ['Emotions', 'Hate and Anger'],
#  95: ['Entertainment', 'Music', 'KPop'],
#  96: ['Phones and Technology'],
#  97: ['Physical Attributes', 'Descriptions'],
#  98: ['Social Media', 'Social Media Accounts'],
#  99: ['Physical Attributes', 'Descriptions'],
#  100: ['Entertainment', 'Music', 'KPop'],
#  101: ['Physical Attributes', 'Breath and Smell']}

# %%
threshold = 0.019
topic_distr.set_index(df_tweets.loc[pd.notna(df_tweets['filtered_text'])].index)
df_topic_distr = get_relevant_topics(topic_distr, threshold=threshold, topic_names=topics_dict)
df_final = combine_datasets(df_tweets, df_topic_distr)

# %%
# Add original tweet's topics to every retweet
for idx,row in df_final.iterrows():
    if (row['type'] == 'RT'):
        df_final.loc[idx, ['topics_list', 'topics_list_general', 'topics_list_specific']] = df_final.loc[idx+1, ['topics_list', 'topics_list_general', 'topics_list_specific']]

# %%
df_final
# Out:
#         Unnamed: 0             tweet_id              user_id  \
# 0                0  1587232917985512960  1340915697384209920
# 1                1  1586896938363802112  1113923052084113024
# 2                2  1587232917947929088   768539405472542720
# 3                3  1587232917972999936  1582752440780313088
# 4                4  1587109985929945088  1262722155357199872
# ...            ...                  ...                  ...
# 153619      153619  1587006429537313024  1193921600799665920
# 153620      153620  1587263620265742080  1484210607872167936
# 153621      153621  1587263620278234880  1418611699863621888
# 153622      153622  1587263620265778944   962369786301833216
# 153623      153623  1587169467322142976  1477318242179845888
#
#                                                      text  \
# 0       RT @sergioisbetter: ‼️‼️💚SALE ENDING SOON💚‼️‼️...
# 1       ‼️‼️💚SALE ENDING SOON💚‼️‼️\nWatch our latest h...
# 2       Now playing: WJIC Network ID by The WJIC Netwo...
# 3       RT @Kyzef: Good morning mfers ☀️ Hope everybod...
# 4       Good morning mfers ☀️ Hope everybody has a gre...
# ...                                                   ...
# 153619            she's so cute 😭 https://t.co/dwTqW8NVY2
# 153620  RT @charts_k: [Exclusive] K-media reports @BTS...
# 153621  @QuoteSunTzu My shield is proud for my blade l...
# 153622  RT @coyodee__: So is it mombod Monday, milf or...
# 153623  So is it mombod Monday, milf or milfshake mond...
#
#                             created_at  in_reply_to_status_id  \
# 0       Mon Oct 31 23:59:51 +0000 2022                    NaN
# 1       Mon Oct 31 01:44:47 +0000 2022                    NaN
# 2       Mon Oct 31 23:59:51 +0000 2022                    NaN
# 3       Mon Oct 31 23:59:51 +0000 2022                    NaN
# 4       Mon Oct 31 15:51:22 +0000 2022                    NaN
# ...                                ...                    ...
# 153619  Mon Oct 31 08:59:52 +0000 2022                    NaN
# 153620  Tue Nov 01 02:01:51 +0000 2022                    NaN
# 153621  Tue Nov 01 02:01:51 +0000 2022           1.587248e+18
# 153622  Tue Nov 01 02:01:51 +0000 2022                    NaN
# 153623  Mon Oct 31 19:47:43 +0000 2022                    NaN
#
#         in_reply_to_user_id  quote_count  reply_count  retweet_count  ...  \
# 0                       NaN            0            0              0  ...
# 1                       NaN            2           10            787  ...
# 2                       NaN            0            0              0  ...
# 3                       NaN            0            0              0  ...
# 4                       NaN            0           23              8  ...
# ...                     ...          ...          ...            ...  ...
# 153619                  NaN            7            1             93  ...
# 153620                  NaN            0            0              0  ...
# 153621         1.434815e+18            0            0              0  ...
# 153622                  NaN            0            0              0  ...
# 153623                  NaN            2           63            242  ...
#
#                                            tokenized_text  \
# 0                                                     NaN
# 1       $EMOJI$SALE ENDING SOON$EMOJI$Watch our latest...
# 2       Now playing: WJIC Network ID by The WJIC Netwo...
# 3                                                     NaN
# 4       Good morning mfers $EMOJI$ Hope everybody has ...
# ...                                                   ...
# 153619                        she's so cute $EMOJI$ $URL$
# 153620                                                NaN
# 153621  $MENTION$ My shield is proud for my blade lies...
# 153622                                                NaN
# 153623  So is it mombod Monday, milf or milfshake mond...
#
#                                              stemmed_text  \
# 0                                                     NaN
# 1        sale end soon watch latest hottest collab new...
# 2           play wjic network id wjic network listen live
# 3                                                     NaN
# 4           good morn mfer hope everybodi great halloween
# ...                                                   ...
# 153619                                               cute
# 153620                                                NaN
# 153621                      shield proud blade lie hidden
# 153622                                                NaN
# 153623   mombod monday milf milfshak monday massiv mam...
#
#                    hashtags      emojis smileys numbers  \
# 0                        []          []      []      []
# 1                        []  ['💚', '💚']      []      []
# 2                        []          []      []      []
# 3                        []          []      []      []
# 4                        []       ['☀']      []      []
# ...                     ...         ...     ...     ...
# 153619                   []       ['😭']      []      []
# 153620                   []          []      []      []
# 153621                   []          []      []      []
# 153622                   []          []      []      []
# 153623  ['#HappyHalloween']  ['🍼', '💦']      []  [' 3']
#
#                                                      urls  \
# 0                                                      []
# 1       ['https://t.co/kGpSdd3HUR', 'https://t.co/MPkU...
# 2                             ['https://t.co/Lzezf1IpOn']
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 153619                        ['https://t.co/dwTqW8NVY2']
# 153620                                                 []
# 153621                                                 []
# 153622                                                 []
# 153623                        ['https://t.co/8V1J1gfoof']
#
#                                               topics_list  \
# 0       {'Topics': [0, 6, 22, 28, 33], 'Scores': [0.02...
# 1       {'Topics': [0, 6, 22, 28, 33], 'Scores': [0.02...
# 2       {'Topics': [0, 2, 4, 5, 6, 8, 10, 15, 16, 18, ...
# 3       {'Topics': [1, 71, 72], 'Scores': [0.021520933...
# 4       {'Topics': [1, 71, 72], 'Scores': [0.021520933...
# ...                                                   ...
# 153619  {'Topics': [22, 30, 67, 97], 'Scores': [0.0204...
# 153620  {'Topics': [49, 75, 76, 80, 91], 'Scores': [0....
# 153621  {'Topics': [49, 75, 76, 80, 91], 'Scores': [0....
# 153622                       {'Topics': [], 'Scores': []}
# 153623                       {'Topics': [], 'Scores': []}
#
#                                       topics_list_general  \
# 0       {'Topics': ('Social Media', 'Finance', 'Genera...
# 1       {'Topics': ('Social Media', 'Finance', 'Genera...
# 2       {'Topics': ('Social Media', 'Entertainment', '...
# 3       {'Topics': ('General Expressions'), 'Scores': ...
# 4       {'Topics': ('General Expressions'), 'Scores': ...
# ...                                                   ...
# 153619  {'Topics': ('General Expressions', 'Physical A...
# 153620  {'Topics': ('Sports', 'Other', 'General Expres...
# 153621  {'Topics': ('Sports', 'Other', 'General Expres...
# 153622                       {'Topics': (), 'Scores': ()}
# 153623                       {'Topics': (), 'Scores': ()}
#
#                                      topics_list_specific
# 0       {'Topics': ('Contest Participation', 'Cryptocu...
# 1       {'Topics': ('Contest Participation', 'Cryptocu...
# 2       {'Topics': ('Contest Participation', 'Music', ...
# 3       {'Topics': ('Hope and Expectation'), 'Scores':...
# 4       {'Topics': ('Hope and Expectation'), 'Scores':...
# ...                                                   ...
# 153619  {'Topics': ('Positive Expressions', 'Gratitude...
# 153620  {'Topics': ('Fighting and Combat Sports', 'Sho...
# 153621  {'Topics': ('Fighting and Combat Sports', 'Sho...
# 153622                       {'Topics': (), 'Scores': ()}
# 153623                       {'Topics': (), 'Scores': ()}
#
# [153624 rows x 24 columns]

# %%
PATH = 'Data/Original dataset 11-2022/'
FILE_NAME = 'tweets_with_topics'

df_final.to_excel(PATH+FILE_NAME+'.xlsx')
