# %% [markdown]
# # Topic Visualization

# %% [markdown]
# ## Initialization

# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic
import pickle
from sklearn.feature_extraction.text import CountVectorizer
import os

# %%
PATH_DIR = './'
os.chdir(PATH_DIR)

# %% [markdown]
# ## Functions

# %%
##################################### GET FILES #####################################

def load_pickle(filename, PATH_FILES, file_ending):
    try:
        with open(PATH_FILES+filename+file_ending+'.pickle', 'rb') as handle:
            object = pickle.load(handle)
        print(filename+file_ending+" file loaded")
        return object
    except:
        return None

def load_model(PATH_MODEL):
    topic_model = BERTopic.load(PATH_MODEL)
    print("BERT model file loaded")
    return topic_model

def get_files(PATH_FILES, file_ending, PATH_MODEL):
    corpus = load_pickle("corpus", PATH_FILES, file_ending)
    embeddings = load_pickle("embeddings", PATH_FILES, file_ending)
    topic_model = load_model(PATH_MODEL)
    return topic_model, corpus, embeddings

##################################### VISUALIZATION #####################################

def visualize_hierarchy_(topic_model, corpus):
    hierarchical_topics = topic_model.hierarchical_topics(corpus)
    return topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)

def reduce_topics_(topic_model, corpus, n_topics=None):
    if (n_topics is None):
        topic_model.reduce_topics(corpus, nr_topics="auto")
    else:
        topic_model.reduce_topics(corpus, nr_topics=n_topics)

def merge_topics_(topic_model, corpus, topic_list):
    topic_model.merge_topics(corpus, topic_list)

def update_with_vectorizer(topic_model, corpus):
    vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 3))#, min_df=50, max_features=20_000)
    topic_model.update_topics(corpus, vectorizer_model=vectorizer_model)
    return topic_model

# %% [markdown]
# ## Model loading

# %%
file_ending = '_2022_v4'
PATH_FILES = 'Data/bert_out/'
PATH_MODEL = PATH_FILES + 'bert_fitted_model'+file_ending+'/'

topic_model, corpus, embeddings = get_files(PATH_FILES, file_ending, PATH_MODEL)
# Out:
# corpus_2022_v4 file loaded
# embeddings_2022_v4 file loaded
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# BERT model file loaded

# %% [markdown]
# ## Visualization

# %%
topic_stats_df = topic_model.get_topic_info()
topic_stats_df
# Out:
#      Topic  Count                                   Name  \
# 0       -1  58626                  -1_like_rt_one_people
# 1        0   2442             0_song_album_music_spotify
# 2        1   2225            1_trump_biden_president_fbi
# 3        2   2176         2_ukraine_russian_russia_putin
# 4        3   1626             3_movie_film_episode_watch
# ..     ...    ...                                    ...
# 130    129    108  129_tour_concert_world tour_love tour
# 131    130    106     130_shes_hes_shes pretty_shes shes
# 132    131    105    131_lisa_celine_lalisa_lalisa human
# 133    132    104        132_breath_smell_breathe_smells
# 134    133    104        133_musk_elon_elon musk_twitter
#
#                                         Representation  Representative_Docs
# 0    [like, rt, one, people, get, follow, love, im,...                  NaN
# 1    [song, album, music, spotify, songs, listen, p...                  NaN
# 2    [trump, biden, president, fbi, donald, donald ...                  NaN
# 3    [ukraine, russian, russia, putin, ukrainian, w...                  NaN
# 4    [movie, film, episode, watch, scene, trailer, ...                  NaN
# ..                                                 ...                  ...
# 130  [tour, concert, world tour, love tour, october...                  NaN
# 131  [shes, hes, shes pretty, shes shes, pretty, he...                  NaN
# 132  [lisa, celine, lalisa, lalisa human, human cel...                  NaN
# 133  [breath, smell, breathe, smells, cant breathe,...                  NaN
# 134  [musk, elon, elon musk, twitter, buy twitter, ...                  NaN
#
# [135 rows x 5 columns]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id
                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["follow hours_hours rt_rt follow_hours_rt","","","idr hours_follow idr_idr_hours rt_hours"],"x":[0.0,0.5459425512402376,0.5459425512402376,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["proof_join_post proof_join discord_rt join","","","hours rt_hours_rt follow_follow hours_idr hours"],"x":[0.0,0.6893666338897597,0.6893666338897597,0.5459425512402376],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["giveaway_follow_retweet_follow giveaway_rt","","","tweet_twitter_retweet_tweets_follow"],"x":[0.0,0.7180259718371891,0.7180259718371891,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["rt_rt rt_rts_follow_soon rt","","","tweet_twitter_retweet_tweets_follow"],"x":[0.0,0.8337789031692221,0.8337789031692221,0.7180259718371891],"xaxis":"x","y":[-35.0,-35.0,-50.0,-50.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["tag_tag friends_wl_friends_giveaway","","","whitelist_tag_whitelist spots_spots_tag friends"],"x":[0.0,0.31809801694359197,0.31809801694359197,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["tweet_twitter_retweet_tweets_rt","","","tag_tag friends_friends_wl_enter"],"x":[0.8337789031692221,0.9809092176558126,0.9809092176558126,0.31809801694359197],"xaxis":"x","y":[-42.5,-42.5,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["hours rt_hours_rt follow_rt_idr hours","","","tag_follow_tag friends_giveaway_rt"],"x":[0.6893666338897597,1.1128498880297433,1.1128498880297433,0.9809092176558126],"xaxis":"x","y":[-12.5,-12.5,-56.25,-56.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["nft_nfts_collection_nft project_project","","","crypto_token_bnb_trading_buy"],"x":[0.0,0.7781153420403306,0.7781153420403306,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["crypto_nft_token_trading_bnb","","","project_projects_team_community_great"],"x":[0.7781153420403306,0.8663735316339702,0.8663735316339702,0.0],"xaxis":"x","y":[-100.0,-100.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["airdrop_referral_bot_distribution_reward","","","project_crypto_nft_token_bnb"],"x":[0.0,0.9171148279565846,0.9171148279565846,0.8663735316339702],"xaxis":"x","y":[-85.0,-85.0,-107.5,-107.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["lie_liar_lies_lying_truth","","","hate_mad_hater_hate hate_angry"],"x":[0.0,0.9650032644907007,0.9650032644907007,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["black_white_racist_racism_white people","","","women_trans_ ...

# %% [markdown]
# ## Topic reduction (auto)

# %%
reduce_topics_(topic_model, corpus)
# Out:
# 2024-06-25 13:06:32,213 - BERTopic - Topic reduction - Reducing number of topics
# 2024-06-25 13:06:47,375 - BERTopic - Topic reduction - Reduced number of topics from 135 to 103

# %%
topic_stats_df = topic_model.get_topic_info()
topic_stats_df
# Out:
#      Topic  Count                                     Name  \
# 0       -1  58626                    -1_like_rt_one_people
# 1        0   5651            0_tag_follow_giveaway_retweet
# 2        1   2987  1_birthday_happy birthday_happy_morning
# 3        2   2442               2_song_album_music_spotify
# 4        3   2225              3_trump_biden_president_fbi
# ..     ...    ...                                      ...
# 98      97    110     97_cute cute_cute_cutest_cute cutest
# 99      98    109  98_account_suspended_instagram_accounts
# 100     99    106        99_shes_hes_shes pretty_shes shes
# 101    100    105      100_lisa_celine_lalisa_lalisa human
# 102    101    104          101_breath_smell_breathe_smells
#
#                                         Representation  \
# 0    [like, rt, one, people, get, follow, love, tim...
# 1    [tag, follow, giveaway, retweet, tag friends, ...
"],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.014963051232054526,0.017195960752730794,0.018263293757868244,0.02844744132683985,0.028710046818932054],"y":["breakfast  ","dinner  ","cake  ","eat  ","food  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.014679618815192873,0.01670428321386938,0.019109136602828453,0.020803932377192767,0.025913145305676934],"y":["arsenal  ","messi  ","chelsea  ","league  ","ronaldo  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.019980355807670398,0.02516495222121242,0.02572353227239159,0.02582010443739371,0.02710266631581752],"y":["elon musk  ","elon  ","mom  ","musk  ","dad  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.010826325941681442,0.010884284901981092,0.013066124311564552,0.018934857186723504,0.019328241610931902],"y":["exam  ","teacher  ","education  ","school  ","students  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.021134322768705603,0.02159852689170157,0.0224 ...

# %%
visualize_hierarchy_(topic_model, corpus)
# Out:
# 100%|██████████| 101/101 [00:03<00:00, 27.78it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cea22c03-da76-4d1e-a1e0-42892a0b7f1b" class="plotly-graph-div" style="height:1730px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cea22c03-da76-4d1e-a1e0-42892a0b7f1b")) {                    Plotly.newPlot(                        "cea22c03-da76-4d1e-a1e0-42892a0b7f1b",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["water_climate_soil_climate change_change","","","rain_weather_cold_snow_warm"],"x":[0.0,0.9090942948046824,0.9090942948046824,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["fire_fires_burn_flame_buruin","","","rain_water_climate_weather_cold"],"x":[0.0,0.9680490467407286,0.9680490467407286,0.9090942948046824],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["covid_vaccine_vaccinated_cases_virus","","","mask_masks_wearing_wear_wear mask"],"x":[0.0,0.8726371014094259,0.8726371014094259,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["fire_rain_water_climate_weather","","","covid_mask_vaccine_masks_vaccinated"],"x":[0.9680490467407286,1.015656307559903,1.015656307559903,0.8726371014094259],"xaxis":"x","y":[-12.5,-12.5,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["photo_picture_pic_photos_pictures","","","art_draw_drawing_artist_painting"],"x":[0.0,0.9117457018037797,0.9117457018037797,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["art_photo_picture_draw_pic","","","shirt_check listing_closet_added closet_listing added"],"x":[0.9117457018037797,0.9204885048312882,0.9204885048312882,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["book_books_read_story_reading","","","students_school_education_teacher_exam"],"x":[0.0,0.8503154893986884,0.8503154893986884,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["dad_musk_mom_elon_elon musk","","","see_want_need_sorry_im"],"x":[0.0,0.8497877533586325,0.8497877533586325,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["dad_musk_mom_elon_baby","","","food_eat_cake_dinner_breakfast"],"x":[0.8497877533586325,0.8733884283099875,0.8733884283099875,0.0],"xaxis":"x","y":[-120.0,-120.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["car_flight_fly_texas_train","","","food_eat_dad_mom_musk"],"x":[0.0,0.8937376103566762,0.8937376103566762,0.8733884283099875],"xaxis":"x","y":[-105.0,-105.0,-127.5,-127.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["food_eat_dad_mom_musk","","","money_pay_cash_debt_credit"],"x":[0.8937376103566762,0.9069940903701417,0.9069940903701417,0.0],"xaxis":"x","y":[-116.25,-116.25,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["book_books_students_school_read","","","food_eat_money_dad_mom"],"x":[0.8503154893986884,0.9177928172720491,0.9177928172720491,0.9069940903701417],"xaxis":"x","y":[-90.0,-90.0,-130. ...

# %% [markdown]
# ## Topic reduction (30)

# %%
topic_model = load_model(PATH_MODEL)
# Out:
# BERT model file loaded

# %%
reduce_topics_(topic_model, corpus, n_topics=30)
# Out:
# 2024-06-25 09:37:10,727 - BERTopic - Topic reduction - Reducing number of topics
# 2024-06-25 09:37:19,601 - BERTopic - Topic reduction - Reduced number of topics from 135 to 30

# %%
topic_stats_df = topic_model.get_topic_info()
topic_stats_df
# Out:
#     Topic  Count                                     Name  \
# 0      -1  58626                       -1_like_rt_one_get
# 1       0   6994                      0_love_im_like_want
# 2       1   6067                 1_song_video_album_music
# 3       2   4125  2_birthday_morning_happy_happy birthday
# 4       3   3807         3_trump_biden_abortion_president
# 5       4   3734        4_tag_follow_giveaway_tag friends
# 6       5   3381                     5_art_hair_moon_look
# 7       6   2760           6_ukraine_russia_russian_putin
# 8       7   2507                   7_god_ji_india_nigeria
# 9       8   2355                8_team_game_season_league
# 10      9   1761           9_twitter_tweet_retweet_follow
# 11     10   1647             10_project_book_books_school
# 12     11   1345                  11_food_eat_cake_dinner
# 13     12    978       12_thank_cute_congratulations_nice
# 14     13    952           13_rt_hours rt_hours_rt follow
# 15     14    946               14_jennie_miss_lisa_chanel
# 16     15    929          15_jungkook_taehyung_kim_tiktok
# 17     16    649              16_covid_mask_vaccine_masks
# 18     17    632            17_dream_hope_dreams_remember
# 19     18    401                     18_dog_cat_cats_dogs
# 20     19    376                 19_vote_voting_votes_gap
# 21     20    343                  20_fight_shot_gun_tyson
# 22     21    302     21_done done_done_done thank_im done
# 23     22    178     22_water_climate_soil_climate change
# 24     23    169     23_jimin_park jimin_park_jimin jimin
# 25     24    125                     24_gt_gt gt_lt_gt lt
# 26     25    125       25_gemini_virgo_pisces_sagittarius
# 27     26    121               26_bts_run bts_run_idk bts
# 28     27    118                 27_fire_fires_burn_flame
# 29     28    110             28_phone_iphone_phones_apple
#
#                                        Representation  \
# 0   [like, rt, one, get, people, follow, love, tim...
# 1   [love, im, like, want, heart, friends, crying,...
# 2   [song, video, album, music, new, movie, watch,...
# 3   [birthday, morning, happy, happy birthday, goo...
# 4   [trump, biden, abortion, president, people, fb...
# 5   [tag, follow, giveaway, tag friends, airdrop, ...
# 6   [art, hair, moon, look, eyes, like, photo, blu...
# 7   [ukraine, russia, russian, putin, war, ukraini...
# 8   [god, ji, india, nigeria, allah, khan, pakista...
# 9   [team, game, season, league, ronaldo, player, ...
# 10  [twitter, tweet, retweet, follow, instagram, t...
# 11  [project, book, books, school, students, read,...
# 12  [food, eat, cake, dinner, breakfast, chicken, ...
# 13  [thank, cute, congratulations, nice, congrats,...
# 14  [rt, hours rt, hours, rt follow, follow, idr h...
# 15  [jennie, miss, lisa, chanel, celine, jennie ch...
# 16  [jungkook, taehyung, kim, tiktok, anime, yoong...
# 17  [covid, mask, vaccine, masks, vaccinated, wear...
# 18  [dream, hope, dreams, remember, thinking, thin...
# 19  [dog, cat, cats, dogs, puppy, kitty, pet, pets...
# 20  [vote, voting, votes, gap, vote vote, mass vot...
# 21  [fight, shot, gun, tyson, fighting, ufc, boxin...
# 22  [done done, done, done thank, im done, done po...
# 23  [water, climate, soil, climate change, change,...
# 24  [jimin, park jimin, park, jimin jimin, jimins,...
# 25  [gt, gt gt, lt, gt lt, lt lt, join gt, gt join...
# 26  [gemini, virgo, pisces, sagittarius, scorpio, ...
# 27  [bts, run bts, run, idk bts, bts contain, cont...
# 28  [fire, fires, burn, flame, buruin, firefighter...
# 29  [phone, iphone, phones, apple, android, gig gh...
#
#                                   Representative_Docs
# 0   [mins rt rt like, k hours rt follow, k hours r...
# 1                                [love, love g, love]
# 2   [bts paved way favorite song best selling song...
# 3    [happy birthday, happy birthday, happy birthday]
# 4   [ivanka trump daughter former president donald...
# 5   [giveaway sol x nfts x wl spots enter follow r...
# 6                              [eyes, eyes, work art]
# 7   [russias putins war putin actual russian soldi...
# 8   [today nobody bring happiness except god kabir...
# 9   [get lot hate psg fans say lionel messi treble...
# 10  [hours rt follow rt like quoted tweet, tweet, ...
# 11                         [book, book, best project]
# 12  [terrible making food love eat, breakfast food...
# 13                              [thank, thank, thank]
# 14  [hours rt follow, hours rt follow, hours rt fo...
# 15  [jennie kim arriving chanel fashion show jenni...
# 16   [love kim taehyung, love kim taehyung, jungkook]
# 17  [medical condition symptoms covid due covid lo...
# 18                              [dream, dream, dream]
# 19  [last night played cat game like cat game lot ...
# 20                                 [vote, vote, vote]
# 21                         [fight back, fight, fight]
# 22                               [done, done, done x]
# 23  [humanity faces grave challenge climate change...
# 24                              [jimin, jimin, jimin]
# 25  [sight gt gt gt gt gt gt, gt gt gt, offerpad s...
# 26  [perhaps finally time buy something special sc...
# 27                                    [bts, bts, bts]
# 28                                 [fire, fire, fire]
# 29                           [iphone, iphone, iphone]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02247189-54ed-4d03-9dd7-458287572bac" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02247189-54ed-4d03-9dd7-458287572bac")) {                    Plotly.newPlot(                        "02247189-54ed-4d03-9dd7-458287572bac",                        [{"customdata":[[0,"love | im | like | want | heart",6994],[1,"song | video | album | music | new",6067],[2,"birthday | morning | happy | happy birthday | good morning",4125],[3,"trump | biden | abortion | president | people",3807],[4,"tag | follow | giveaway | tag friends | airdrop",3734],[5,"art | hair | moon | look | eyes",3381],[6,"ukraine | russia | russian | putin | war",2760],[7,"god | ji | india | nigeria | allah",2507],[8,"team | game | season | league | ronaldo",2355],[9,"twitter | tweet | retweet | follow | instagram",1761],[10,"project | book | books | school | students",1647],[11,"food | eat | cake | dinner | breakfast",1345],[12,"thank | cute | congratulations | nice | congrats",978],[13,"rt | hours rt | hours | rt follow | follow",952],[14,"jennie | miss | lisa | chanel | celine",946],[15,"jungkook | taehyung | kim | tiktok | anime",929],[16,"covid | mask | vaccine | masks | vaccinated",649],[17,"dream | hope | dreams | remember | thinking",632],[18,"dog | cat | cats | dogs | puppy",401],[19,"vote | voting | votes | gap | vote vote",376],[20,"fight | shot | gun | tyson | fighting",343],[21,"done done | done | done thank | im done | done po",302],[22,"water | climate | soil | climate change | change",178],[23,"jimin | park jimin | park | jimin jimin | jimins",169],[24,"gt | gt gt | lt | gt lt | lt lt",125],[25,"gemini | virgo | pisces | sagittarius | scorpio",125],[26,"bts | run bts | run | idk bts | bts contain",121],[27,"fire | fires | burn | flame | buruin",118],[28,"phone | iphone | phones | apple | android",110]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":
"],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013178255554548308,0.0135143068680481,0.013845532575607167,0.01396958359742866,0.015267144818411694],"y":["ronaldo  ","league  ","season  ","game  ","team  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03764171660224301,0.03897373281019771,0.046208178158319534,0.05770453627891337,0.06686252546017318],"y":["instagram  ","follow  ","retweet  ","tweet  ","twitter  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013583524672634783,0.013909294643663181,0.01423277993616551,0.017387364828181415,0.03164770291727901],"y":["students  ","school  ","books  ","book  ","project  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.016480248347830427,0.01916254226635937,0.020247842810193824,0.03323185470289279,0.034226343915106955],"y":["breakfast  ","dinner  ","cake  ","eat  ","food  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.11516866112311053,0.11869841730783315,0.12473160524198944,0.13967916908595251,0.30057455941754074],"y":["congrats  ","nice  ","congratulations  ","cute  ","thank  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.11596122255656881,0.1297524065885 ...

# %%
visualize_hierarchy_(topic_model, corpus)
# Out:
# 100%|██████████| 28/28 [00:00<00:00, 33.00it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d14cdd38-e390-41e1-b9c6-8d9d03290195" class="plotly-graph-div" style="height:635px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d14cdd38-e390-41e1-b9c6-8d9d03290195")) {                    Plotly.newPlot(                        "d14cdd38-e390-41e1-b9c6-8d9d03290195",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["trump_biden_abortion_president_people","","","god_ji_india_nigeria_allah"],"x":[0.0,0.6656561183987311,0.6656561183987311,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["ukraine_russia_russian_putin_war","","","trump_people_god_president_biden"],"x":[0.0,0.7666203941612293,0.7666203941612293,0.6656561183987311],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["ukraine_trump_russia_russian_people","","","covid_mask_vaccine_masks_vaccinated"],"x":[0.7666203941612293,0.8725505929293985,0.8725505929293985,0.0],"xaxis":"x","y":[-22.5,-22.5,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["water_climate_soil_climate change_change","","","ukraine_trump_russia_russian_people"],"x":[0.0,0.9313515946102554,0.9313515946102554,0.8725505929293985],"xaxis":"x","y":[-5.0,-5.0,-33.75,-33.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["love_im_like_want_heart","","","song_video_album_music_new"],"x":[0.0,0.5789666598166754,0.5789666598166754,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["art_hair_moon_look_eyes","","","love_song_like_video_im"],"x":[0.0,0.6586107431868878,0.6586107431868878,0.5789666598166754],"xaxis":"x","y":[-75.0,-75.0,-90.0,-90.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["team_game_season_league_ronaldo","","","project_book_books_school_students"],"x":[0.0,0.7196712940761758,0.7196712940761758,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["love_song_like_video_im","","","project_team_game_season_league"],"x":[0.6586107431868878,0.7437769653717026,0.7437769653717026,0.7196712940761758],"xaxis":"x","y":[-82.5,-82.5,-110.0,-110.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["birthday_morning_happy_happy birthday_good morning","","","love_like_one_song_get"],"x":[0.0,0.7898802816998519,0.7898802816998519,0.7437769653717026],"xaxis":"x","y":[-65.0,-65.0,-96.25,-96.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["love_like_good_happy_one","","","food_eat_cake_dinner_breakfast"],"x":[0.7898802816998519,0.827164635959163,0.827164635959163,0.0],"xaxis":"x","y":[-80.625,-80.625,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["dream_hope_dreams_remember_thinking","","","love_like_good_happy_one"],"x":[0.0,0.8891347528295533,0.8891347528295533,0.827164635959163],"xaxis":"x","y":[-55.0,-55.0,-102.8125,-102.8125],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["fight_shot_gun_tyson_fighting","","","dog_cat_cats_dogs_puppy"],"x":[0.0,0.936267948683975,0.936267948683975,0.0],"xaxis":"x","y":[-135.0,-135.0,-145 ...
